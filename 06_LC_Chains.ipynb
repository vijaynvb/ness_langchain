# %% [markdown]
# # **Chains**
#
# chains are a fundamental concept that allows you to execute complex tasks in a structured and efficient way.
#
# ## **Why Chains?**
#
# Chains are invaluable due to their capacity to effortlessly blend diverse components, shaping a singular and coherent application. Through the creation of chains, multiple elements can seamlessly come together. Imagine this scenario: a chain is crafted to take in user input, polish it using a PromptTemplate, and subsequently pass on this refined response to a large language model (LLM). This streamlined process not only simplifies but also enriches the overall functionality of the system. In essence, chains serve as the linchpin, seamlessly connecting different parts of the application and enhancing its capabilities.

# %%
# %%capture
# update or install the necessary libraries
# !pip install --upgrade langchain langchain_community langchain_aws langchain_classic
# !pip install --upgrade python-dotenv

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

os.environ["AWS_ACCESS_KEY_ID"] = os.getenv('AWS_ACCESS_KEY_ID')
os.environ["AWS_SECRET_ACCESS_KEY"] = os.getenv('AWS_SECRET_ACCESS_KEY')
os.environ["AWS_DEFAULT_REGION"] =os.getenv('AWS_DEFAULT_REGION')

# %% [markdown]
# # **LLM Chain** - **The simplest chain**
#
# The LLMChain is a foundational system that includes a PromptTemplate, an OpenAI model (such as a Large Language Model or a ChatModel), and optionally, an output parser. It operates by transforming input parameters using the PromptTemplate into a coherent prompt, which is then fed into the model. The resulting output is further refined and formatted into a usable form by the OutputParser, if provided. This structured approach ensures effective utilization of language models for various applications, enhancing their functionality and utility.

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_classic.chains import LLMChain

# %%
from langchain_aws import ChatBedrock

llm = ChatBedrock(
    model_id="mistral.mistral-7b-instruct-v0:2",
    temperature=0.5
)

# %%
prompt = ChatPromptTemplate.from_template(
    "What are the tools that need to be learned to earn the {designation}?,provide me one tool"
)

# %%
chain = LLMChain(llm=llm, prompt=prompt)

# %%
designation = "Devops Engineer"
chain.run(designation)
# Out:
# ' To become a successful DevOps Engineer, you need to have a good understanding of various tools and technologies that enable continuous integration, continuous delivery, infrastructure automation, and monitoring. Here are some of the most commonly used tools in the DevOps space:\n\n1. Version Control Systems (VCS) like Git or SVN\n2. Continuous Integration (CI) tools like Jenkins, Travis CI, or CircleCI\n3. Continuous Delivery (CD) tools like Spinnaker, Ansible Tower, or Jenkins X\n4. Infrastructure Automation tools like Terraform, Ansible, or Puppet\n5. Containerization tools like Docker or Kubernetes\n6. Configuration Management tools like Ansible, Chef, or Puppet\n7. Monitoring and Logging tools like Nagios, Prometheus, or ELK Stack\n8. Orchestration tools like Apache Hadoop, Apache Spark, or Apache Kafka\n9. Source Code Management tools like GitHub, Bitbucket, or GitLab\n10. Cloud Platforms like AWS, Azure, or Google Cloud\n\nOne of the most commonly used tools in the DevOps space is Jenkins, an open-source automation server. Jenkins is used for continuous integration, continuous delivery, and continuous deployment. It supports a wide range of plugins, making it a versatile tool for automating various stages of the software development lifecycle. With Jenkins, you can build, test, and deploy your code automatically, reducing the time and effort required to release new software updates. Additionally, Jenkins integrates with many other DevOps tools, making it a popular choice for DevOps engineers.'

# %% [markdown]
# # **SimpleSequentialChain**
#
# Simple Sequential Chains allow for a single input to undergo a series of coherent transformations, resulting in a refined output. This sequential approach ensures systematic and efficient handling of data, making it ideal for scenarios where a linear flow of information processing is essential

# %%
# SimpleSequentialChain
from langchain_classic.chains import SimpleSequentialChain
from langchain_core.prompts import ChatPromptTemplate
from langchain_classic.chains import LLMChain

# %%
# prompt template 1
first_prompt = ChatPromptTemplate.from_template(
    "What are the tools that need to be learned to earn the {designation}?,provide me one tool"
)

# Chain 1
chain_one = LLMChain(llm=llm, prompt=first_prompt)

# %%
# prompt template 2
second_prompt = ChatPromptTemplate.from_template(
    "Write a 20 words description for the following \
    tool:{tool_name}"
)
# chain 2
chain_two = LLMChain(llm=llm, prompt=second_prompt)

# %%
overall_simple_chain = SimpleSequentialChain(chains=[chain_one, chain_two],
                                             verbose=True
                                            )

# %%
overall_simple_chain.run(designation)
# Out:
# > Entering new SimpleSequentialChain chain...
#  To become a DevOps Engineer, you should have a good understanding of various tools and technologies that enable continuous integration, continuous delivery, infrastructure automation, and monitoring. Here are some of the most commonly used tools in the DevOps toolchain:
#
# 1. Version Control Systems (VCS): Git is the most popular version control system used in DevOps. It allows teams to manage and track changes to their codebase, collaborate on projects, and roll back changes if necessary.
# 2. Continuous Integration (CI) and Continuous Delivery (CD) tools: Jenkins, Travis CI, CircleCI, and GitLab CI/CD are popular tools for automating the build, testing, and deployment of applications. They help teams to detect and fix issues early, reduce the time to market, and ensure that code is always in a deployable state.
# 3. Containerization: Docker is the most widely used containerization technology. It allows developers to package their applications and dependencies into containers, making it easier to deploy and manage applications across different environments.
# 4. Configuration Management: Ansible, Puppet, and Chef are popular configuration management tools used in DevOps. They help automate the deployment, configuration, and management of infrastructure and applications.
# 5. Infrastructure as Code (IaC): Terraform and CloudFormation are popular IaC tools used to define and manage infrastructure as code. They help teams to automate the provisioning and configuration of infrastructure, making it easier to manage and scale.
# 6. Monitoring and Logging: Tools like Nagios, Zabbix, and ELK Stack (Elasticsearch, Logstash, and Kibana) are used for monitoring and logging. They help teams to detect and respond to issues in real-time, ensuring that applications and infrastructure are performing optimally.
#
# One popular tool that fits into multiple categories is Docker. It can be used as a containerization technology, as well as a platform for running applications and services. Additionally, Docker can be used in conjunction with other tools, such as Jenkins, to create a complete DevOps pipeline.
#  DevOps Toolchain: Git (VCS) for code management, Jenkins/Travis CI/CircleCI (CI/CD) for automating builds and deployments, Docker (containerization) for packaging apps, Ansible/Puppet/Chef (configuration management) for infrastructure automation, Terraform/CloudFormation (IaC) for infrastructure provisioning, and Nagios/Zabbix/ELK Stack (monitoring/logging) for performance optimization. Docker is a versatile tool that can be used for containerization, running apps, and integrating with CI/CD pipelines.
#
# > Finished chain.
# ' DevOps Toolchain: Git (VCS) for code management, Jenkins/Travis CI/CircleCI (CI/CD) for automating builds and deployments, Docker (containerization) for packaging apps, Ansible/Puppet/Chef (configuration management) for infrastructure automation, Terraform/CloudFormation (IaC) for infrastructure provisioning, and Nagios/Zabbix/ELK Stack (monitoring/logging) for performance optimization. Docker is a versatile tool that can be used for containerization, running apps, and integrating with CI/CD pipelines.'

# %% [markdown]
# # **SequentialChain**
#
# A sequential chain is a chain that combines various individual chains, where the output of one chain serves as the input for the next in a continuous sequence. It operates by running a series of chains consecutively.

# %%
# SequentialChain
from langchain_classic.chains import SequentialChain

# %%
# prompt template 1: translate to english
first_prompt = ChatPromptTemplate.from_template(
    "Write a 20 words description for the following designation"
    "\n\n{Designation}"
)
# chain 1: input= Review and output= English_Review
chain_one = LLMChain(llm=llm, prompt=first_prompt,
                     output_key="Designation_description"
                    )

# %%
second_prompt = ChatPromptTemplate.from_template(
    "Can you summarize the following description in 1 sentence:"
    "\n\n{Designation_description}"
)
# chain 2: input= English_Review and output= summary
chain_two = LLMChain(llm=llm, prompt=second_prompt,
                     output_key="summary"
                    )

# %%
# prompt template 3: translate to english
third_prompt = ChatPromptTemplate.from_template(
    "What are the promgramming language that need to be learned for this designation in one line:\n\n{Designation}"
)
# chain 3: input= Review and output= language
chain_three = LLMChain(llm=llm, prompt=third_prompt,
                       output_key="programming_language"
                      )

# %%
# prompt template 4: follow up message
fourth_prompt = ChatPromptTemplate.from_template(
    "Write a short follow up response to the following "
    "Write a short summary about the programming language:"
    "\n\nSummary: {summary}\n\nLanguage: {programming_language}"
)
# chain 4: input= summary, language and output= followup_message
chain_four = LLMChain(llm=llm, prompt=fourth_prompt,
                      output_key="followup_message"
                     )

# %%
# overall_chain: input= Review
# and output= English_Review,summary, followup_message
overall_chain = SequentialChain(
    chains=[chain_one, chain_two, chain_three, chain_four],
    input_variables=["Designation"],
    output_variables=["Designation_description","programming_language", "summary","followup_message"],
    verbose=True
)

# %%
designation = "AI Engineer"
overall_chain(designation)
# Out:
# /var/folders/rm/gvl01dcd5dg9dxwkn8zgg9v40000gn/T/ipykernel_68621/2010498844.py:2: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain-classic 0.1.0 and will be removed in 2.0.0. Use `invoke` instead.
#   overall_chain(designation)
# > Entering new SequentialChain chain...
#
# > Finished chain.
# {'Designation': 'AI Engineer',
#  'Designation_description': ' An AI Engineer designs, develops, and implements artificial intelligence systems using machine learning algorithms, neural networks, and deep learning technologies. They optimize and maintain AI models, ensuring high performance and accuracy.',
#  'programming_language': " To become an AI Engineer, you're typically expected to have a strong foundation in Linux, Python for data manipulation (NumPy, Pandas, Scikit-Learn), machine learning frameworks like TensorFlow or PyTorch, deep learning libraries, and knowledge of databases and big data processing systems like Hadoop or Spark. Additionally, familiarity with data visualization tools (Matplotlib, Seaborn), version control systems (Git), and cloud platforms (AWS, Google Cloud, Microsoft Azure) is often required.",
#  'summary': ' An AI Engineer builds and maintains artificial intelligence systems by designing, developing, and implementing machine learning algorithms, neural networks, and deep learning technologies, and optimizes models for superior performance and accuracy.',
#  'followup_message': " Response:  Your summary accurately captures the key skills and technologies required for an AI Engineer. Python, with its extensive data manipulation libraries and machine learning frameworks, is indeed a popular choice for building and optimizing AI systems. However, it's important to note that other programming languages, such as C++ or Java, may also be used depending on the specific project or organization. Additionally, familiarity with natural language processing libraries, such as NLTK or spaCy, and computer vision libraries, like OpenCV, can also be valuable for AI Engineers working on projects involving text or image data. Overall, the ability to learn and adapt to new tools and technologies is a crucial aspect of being an effective AI Engineer."}

# %% [markdown]
# # **Router Chain**
#
# The Router Chain is used for complicated tasks. If we have multiple subchains, each of which is specialized for a particular type of input, we could have a router chain that decides which subchain to pass the input to.

# %%
software_engineer_template = """You are a highly skilled software engineer. \
You excel at addressing queries about programming and software development in a clear
and straightforward manner. \
When faced with a challenge outside your expertise, you candidly \
acknowledge the gap in your knowledge. \

Here is a question:
{input}"""


database_administrator_template = """You are a highly skilled database administrator.\
You excel at answering questions about databases in a clear and precise manner, \
making even complex topics accessible to anyone.\
When faced with a query or issue you're unfamiliar with, \
you candidly admit that you need to look into it further, valuing accuracy over conjecture.\

Here is a question:
{input}"""

data_scientist_template = """You are a highly skilled data scientist.\
You excel at interpreting complex datasets and presenting insights in a \
straightforward and comprehensible manner.\
When confronted with a query beyond your expertise, you acknowledge \
your limitations and advocate for further research or consultation.

Here is a question:
{input}"""


Machine_learning_engineer_template = """You are a highly skilled Machine Learning Engineer.\
You excel at answering questions about machine learning algorithms and models in a clear and succinct manner.\
When confronted with a query outside your expertise, you candidly admit that you don't have the answer. \

Here is a question:
{input}"""

# %%
prompt_infos = [
    {
        "name": "software_engineer",
        "description": "Good for answering questions about software_engineer",
        "prompt_template": software_engineer_template
    },
    {
        "name": "database_administrator",
        "description": "Good for answering database_administrator questions",
        "prompt_template": database_administrator_template
    },
    {
        "name": "data_scientist",
        "description": "Good for answering data_scientist questions",
        "prompt_template": data_scientist_template
    },
    {
        "name": "Machine_learning_engineer",
        "description": "Good for answering Machine_learning_engineer questions",
        "prompt_template": Machine_learning_engineer_template
    }
]

# %%
from langchain.chains.router import MultiPromptChain
from langchain.chains.router.llm_router import LLMRouterChain,RouterOutputParser
from langchain.prompts import PromptTemplate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 from langchain.chains.router import MultiPromptChain
#       2 from langchain.chains.router.llm_router import LLMRouterChain,RouterOutputParser
#       3 from langchain.prompts import PromptTemplate
#
# ModuleNotFoundError: No module named 'langchain.chains'

# %%
destination_chains = {}
for p_info in prompt_infos:
    name = p_info["name"]
    prompt_template = p_info["prompt_template"]
    prompt = ChatPromptTemplate.from_template(template=prompt_template)
    chain = LLMChain(llm=llm, prompt=prompt)
    destination_chains[name] = chain

destinations = [f"{p['name']}: {p['description']}" for p in prompt_infos]
destinations_str = "\n".join(destinations)

# %%
default_prompt = ChatPromptTemplate.from_template("{input}")
default_chain = LLMChain(llm=llm, prompt=default_prompt)

# %%
MULTI_PROMPT_ROUTER_TEMPLATE = """Given a raw text input to a \
language model select the model prompt best suited for the input. \
You will be given the names of the available prompts and a \
description of what the prompt is best suited for. \
You may also revise the original input if you think that revising\
it will ultimately lead to a better response from the language model.

<< FORMATTING >>
Return a markdown code snippet with a JSON object formatted to look like:
```json
{{{{
    "destination": string \ name of the prompt to use or "DEFAULT"
    "next_inputs": string \ a potentially modified version of the original input
}}}}
```

REMEMBER: "destination" MUST be one of the candidate prompt \
names specified below OR it can be "DEFAULT" if the input is not\
well suited for any of the candidate prompts.
REMEMBER: "next_inputs" can just be the original input \
if you don't think any modifications are needed.

<< CANDIDATE PROMPTS >>
{destinations}

<< INPUT >>
{{input}}

<< OUTPUT (remember to include the ```json)>>"""
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\ '
# <>:12: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/rm/gvl01dcd5dg9dxwkn8zgg9v40000gn/T/ipykernel_49793/2160379643.py:12: SyntaxWarning: invalid escape sequence '\ '
#   "destination": string \ name of the prompt to use or "DEFAULT"

# %%
router_template = MULTI_PROMPT_ROUTER_TEMPLATE.format(
    destinations=destinations_str
)
router_prompt = PromptTemplate(
    template=router_template,
    input_variables=["input"],
    output_parser=RouterOutputParser(),
)

router_chain = LLMRouterChain.from_llm(llm, router_prompt)

# %%
chain = MultiPromptChain(router_chain=router_chain,
                         destination_chains=destination_chains,
                         default_chain=default_chain, verbose=True
                        )
# Out:
# /var/folders/rm/gvl01dcd5dg9dxwkn8zgg9v40000gn/T/ipykernel_49793/2333002322.py:1: LangChainDeprecationWarning: Please see migration guide here for recommended implementation: https://python.langchain.com/docs/versions/migrating_chains/multi_prompt_chain/
#   chain = MultiPromptChain(router_chain=router_chain,

# %%
chain.run("What are the various categories of software?")
# Out:
# > Entering new MultiPromptChain chain...
# software_engineer: {'input': 'What are the different types or categories of software?'}
# > Finished chain.
# " I'm glad you asked about the different types or categories of software. There are several ways to classify software based on their functions, development methods, or deployment models. Here are some common categories:\n\n1. **System Software:** System software is the foundation of any operating system. It manages hardware resources, provides common services for applications, and enables the execution of other software. Examples include operating systems, device drivers, and firmware.\n\n2. **Application Software:** Application software is designed to perform specific tasks for end-users. It can be categorized based on the type of tasks it performs, such as productivity software (Microsoft Office, Google Docs), creative software (Adobe Photoshop, Illustrator), or entertainment software (games, music players).\n\n3. **Web Applications:** Web applications are accessed through a web browser and run on a remote server. They are built using various web technologies like HTML, CSS, JavaScript, and server-side languages like PHP, Ruby, or Python. Examples include email services, social media platforms, and online document editors.\n\n4. **Mobile Applications:** Mobile applications are designed for smartphones and tablets. They can be installed and run on the device itself. Mobile applications can be categorized based on their functionality, such as productivity apps, social media apps, games, or educational apps.\n\n5. **Desktop Applications:** Desktop applications are installed and run on a personal computer. They can be standalone applications or part of a larger software suite. Examples include Microsoft Office, Adobe Creative Suite, and media players.\n\n6. **Cross-platform Applications:** Cross-platform applications can run on multiple operating systems, such as Windows, macOS, Linux, or mobile platforms. They are typically developed using technologies like Java, .NET, or React Native.\n\n7. **Open-source Software:** Open-source software is developed and released with a permissive license, allowing users to view, modify, and distribute the source code. Open-source software can be found in all categories, from operating systems (Linux) to applications (LibreOffice, Firefox).\n\n8. **Proprietary Software:** Proprietary software is developed and owned by a company or individual. Users do not have access to the source code and are typically required to pay a license fee to use the software. Examples include Microsoft Windows, Adobe Creative Suite, and Autodes"

# %%
chain.run("What are the differences between supervised and unsupervised learning")
# Out:
# > Entering new MultiPromptChain chain...
# Machine_learning_engineer: {'input': 'What are the key differences between supervised and unsupervised learning in machine learning?'}
# > Finished chain.
# " I'm glad you asked about the differences between supervised and unsupervised learning in machine learning!\nSupervised learning is a type of machine learning where the model is trained on labeled data. This means that the input data comes with corresponding output labels, and the model learns to map inputs to outputs based on this training data. The goal of supervised learning is to learn a function that can accurately predict the output label for new, unseen input data. Examples of supervised learning algorithms include linear regression, logistic regression, support vector machines, and neural networks.\nUnsupervised learning, on the other hand, is a type of machine learning where the model is trained on unlabeled data. This means that the input data does not come with corresponding output labels, and the model must find patterns and structure in the data on its own. The goal of unsupervised learning is to discover hidden patterns or relationships in the data. Examples of unsupervised learning algorithms include k-means clustering, principal component analysis, and autoencoders.\nOne key difference between supervised and unsupervised learning is the presence or absence of labeled data. Supervised learning requires labeled data to train the model, while unsupervised learning does not. Another difference is the type of tasks they are used for. Supervised learning is typically used for regression or classification tasks, where the goal is to predict a continuous or categorical output label based on input features. Unsupervised learning, on the other hand, is typically used for clustering or dimensionality reduction tasks, where the goal is to find patterns or structure in the data without the need for output labels.\nI hope this explanation helps clarify the differences between supervised and unsupervised learning! Let me know if you have any other questions."

# %% [markdown]
# # **Let's Do an Activity**
#
# ## **Objective**
#
# Practice using chains with language models and structured output parsing to handle complex tasks efficiently.
#
# ## **Scenario**
#
# You are tasked with building a system to assist users in understanding various technical concepts related to software engineering roles. Your goal is to use different chains to process user queries, transform them using prompt templates, and extract specific information using output parsers.
#
# ## **Steps**
#
# * Define a Prompt Template
# * Prepare Sample Queries
# * Implement LLM Chains
# * Output Parsing
# * Interactive Chain Execution
# * Evaluate
